# %%
import numpy as np
from pandas import read_csv as read
import math
import matplotlib.pyplot as plt
path = "C:\Users\user\Downloads\winef.csv"
features = read(path, delimiter=",")
features.head()
# Out:
#    Grade     P1    P2    P3    P4   P5    P6    P7    P8    P9   P10   P11  \
# 0      1  14.23  1.71  2.43  15.6  127  2.80  3.06  0.28  2.29  5.64  1.04
# 1      1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05
# 2      1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03
# 3      1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86
# 4      1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04
#
#     P12   P13
# 0  3.92  1065
# 1  3.40  1050
# 2  3.17  1185
# 3  3.45  1480
# 4  2.93   735

# %%
X = features.values[::, 1:14] #определение фич
Y = features.values[::, 0:1]  #определение лэйблов
learnList1 = []
learnList2 = []
learnList3 = []

# %%
for t in range(50):
    for i in range(12):
        learnList1.append(int(X[t][i]))
for t in range(60,120):
    for i in range(12):
        learnList2.append(int(X[t][i]))
for t in range(131,170):
    for i in range(12):
        learnList2.append(int(X[t][i]))

# %%
learnList1
# Out:
# [[array([  1.42300000e+01,   1.71000000e+00,   2.43000000e+00,
#            1.56000000e+01,   1.27000000e+02,   2.80000000e+00,
#            3.06000000e+00,   2.80000000e-01,   2.29000000e+00,
#            5.64000000e+00,   1.04000000e+00,   3.92000000e+00,
#            1.06500000e+03]), array([ 1.])],
#  [array([  1.32000000e+01,   1.78000000e+00,   2.14000000e+00,
#            1.12000000e+01,   1.00000000e+02,   2.65000000e+00,
#            2.76000000e+00,   2.60000000e-01,   1.28000000e+00,
#            4.38000000e+00,   1.05000000e+00,   3.40000000e+00,
#            1.05000000e+03]), array([ 1.])],
#  [array([  1.31600000e+01,   2.36000000e+00,   2.67000000e+00,
#            1.86000000e+01,   1.01000000e+02,   2.80000000e+00,
#            3.24000000e+00,   3.00000000e-01,   2.81000000e+00,
#            5.68000000e+00,   1.03000000e+00,   3.17000000e+00,
#            1.18500000e+03]), array([ 1.])],
#  [array([  1.43700000e+01,   1.95000000e+00,   2.50000000e+00,
# ...
